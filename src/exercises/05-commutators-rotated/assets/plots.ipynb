# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
fig, (ax1, ax2) = plt.subplots(1,2)

entries = np.genfromtxt('constant_residuals.csv', delimiter=',')

N_values = entries[:,0]
residuals = entries[:,1]
log_N_values = []
log_residuals = []

for N in N_values:
	log_N_values.append(np.log(N) / np.log(10))

for residual in residuals:
	log_residuals.append(np.log(residual) / np.log(10))

ax1.plot(N_values, residuals)
ax1.set(xlabel='$N$ (resolution)', ylabel='$R$ (RMS residual)')
ax1.xaxis.label.set_fontsize(20)
ax1.yaxis.label.set_fontsize(20)

# ax2.plot(N_values, log_residuals)
# ax2.set(xlabel='$N$', ylabel='$log \; R$')
ax2.plot(log_N_values, log_residuals)
ax2.set(xlabel='$\log \; N$', ylabel='$\log \; R$')
ax2.xaxis.label.set_fontsize(20)
ax2.yaxis.label.set_fontsize(20)

fig.suptitle('Constant Residuals', fontsize=30)
fig.set_size_inches(15, 5, forward=True)
fig.set_dpi(100)

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2)

entries = np.genfromtxt('nonconstant_residuals.csv', delimiter=',')

N_values = entries[:,0]
residuals = entries[:,1]
log_N_values = []
log_residuals = []

for N in N_values:
	log_N_values.append(np.log(N) / np.log(10))

for residual in residuals:
	log_residuals.append(np.log(residual) / np.log(10))

ax1.plot(N_values, residuals)
ax1.set(xlabel='$N$ (resolution)', ylabel='$R$ (RMS residual)')
ax1.xaxis.label.set_fontsize(20)
ax1.yaxis.label.set_fontsize(20)

# ax2.plot(N_values, log_residuals)
# ax2.set(xlabel='$N$', ylabel='$log \; R$')
ax2.plot(log_N_values, log_residuals)
ax2.set(xlabel='$\log \; N$', ylabel='$\log \; R$')
ax2.xaxis.label.set_fontsize(20)
ax2.yaxis.label.set_fontsize(20)

fig.suptitle('Non-constant Residuals', fontsize=30)
fig.set_size_inches(15, 5, forward=True)
fig.set_dpi(100)

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2)

entries = np.genfromtxt('nonconstant_alpha_residuals.csv', delimiter=',')

alpha_values = entries[:,0]
residuals = entries[:,1]
log_alpha_values = []
log_residuals = []

for alpha in alpha_values:
	log_alpha_values.append(np.log(alpha) / np.log(10))

for residual in residuals:
	log_residuals.append(np.log(residual) / np.log(10))

ax1.plot(alpha_values, residuals)
ax1.set(xlabel='$alpha$', ylabel='$R$ (RMS residual)')
ax1.xaxis.label.set_fontsize(20)
ax1.yaxis.label.set_fontsize(20)

# ax2.plot(alpha_values, log_residuals)
# ax2.set(xlabel='$alpha$', ylabel='$log \; R$')
ax2.plot(log_alpha_values, log_residuals)
ax2.set(xlabel='$\log \; alpha$', ylabel='$\log \; R$')
ax2.xaxis.label.set_fontsize(20)
ax2.yaxis.label.set_fontsize(20)

fig.suptitle('Non-constant Residuals vs. alpha', fontsize=30)
fig.set_size_inches(15, 5, forward=True)
fig.set_dpi(100)

plt.show()
# Out:
# /tmp/ipykernel_35625/3230054691.py:11: RuntimeWarning: divide by zero encountered in log
#   log_alpha_values.append(np.log(alpha) / np.log(10))
